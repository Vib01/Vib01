# %% [markdown]
# <a href="https://colab.research.google.com/github/Vib01/Vib01/blob/main/processing_image_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#getting image using web get
# !wget 'https://static.wixstatic.com/media/f2b0f7_edada4aca9c6406bbdc87f8e4a14bab4~mv2.jpg/v1/fill/w_3000,h_2000,al_c,q_90/Shelby%20Cobra%20CSX10000%20(1).jpg'
# Out:
# --2024-09-27 00:09:23--  https://static.wixstatic.com/media/f2b0f7_edada4aca9c6406bbdc87f8e4a14bab4~mv2.jpg/v1/fill/w_3000,h_2000,al_c,q_90/Shelby%20Cobra%20CSX10000%20(1).jpg
# Resolving static.wixstatic.com (static.wixstatic.com)... 18.154.144.65, 18.154.144.107, 18.154.144.118, ...
# Connecting to static.wixstatic.com (static.wixstatic.com)|18.154.144.65|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 692234 (676K) [image/jpeg]
# Saving to: ‘Shelby Cobra CSX10000 (1).jpg.1’
#
# Shelby Cobra CSX100 100%[===================>] 676.01K  --.-KB/s    in 0.05s
#
# 2024-09-27 00:09:23 (13.9 MB/s) - ‘Shelby Cobra CSX10000 (1).jpg.1’ saved [692234/692234]

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img = mpimg.imread('/content/Shelby Cobra CSX10000 (1).jpg')

# %%
print(img)
# Out:
# [[[ 42  31  25]
#   [ 43  32  26]
#   [ 44  33  27]
#   ...
#   [ 80  93 110]
#   [ 80  93 110]
#   [ 80  93 110]]
#
#  [[ 42  31  25]
#   [ 42  31  25]
#   [ 43  32  26]
#   ...
#   [ 80  93 110]
#   [ 80  93 110]
#   [ 80  93 110]]
#
#  [[ 40  31  24]
#   [ 40  31  24]
#   [ 41  32  25]
#   ...
#   [ 80  93 110]
#   [ 80  93 110]
#   [ 80  93 110]]
#
#  ...
#
#  [[121 111 109]
#   [121 111 109]
#   [121 111 109]
#   ...
#   [153 140 123]
#   [156 143 126]
#   [157 144 127]]
#
#  [[122 111 109]
#   [122 111 109]
#   [122 111 109]
#   ...
#   [155 142 125]
#   [157 144 127]
#   [158 145 128]]
#
#  [[123 112 110]
#   [123 112 110]
#   [123 112 110]
#   ...
#   [156 143 126]
#   [157 144 127]
#   [159 146 129]]]

# %%
img_plot=plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from PIL import Image
img=Image.open('/content/Shelby Cobra CSX10000 (1).jpg')
img_resize= img.resize((200,200))

# %%
img_resize.save('car_image_resize.jpg')

# %%
img_res = mpimg.imread('/content/car_image_resize.jpg')
plotimg=plt.imshow(img_resize)
plt.show()

# %%
#convert rgb to grayscale
import cv2

# %%
img=cv2.imread('/content/Shelby Cobra CSX10000 (1).jpg.1')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
grayscale_img=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
cv2.imshow('grayscale_img')
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-24-26e3d00b7835> in <cell line: 1>()
# ----> 1 cv2.imshow('grayscale_img')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      46   def wrapped(*args, **kwargs):
#      47     if not os.environ.get(env_var, False):
# ---> 48       raise DisabledFunctionError(message, name or func.__name__)
#      49     return func(*args, **kwargs)
#      50
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %%
#not allowed in google colab, soo
from google.colab.patches import cv2_imshow

# %%
#dispalying image
cv2_imshow(grayscale_img)
# Out:
# <PIL.Image.Image image mode=L size=3000x2000>
